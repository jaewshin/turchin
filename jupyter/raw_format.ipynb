# %%
# %load_ext sql

# %%
# %sql postgresql://riceuser:js94@localhost/ricedb
# Out:
# 'Connected: riceuser@ricedb'

# %%
# %%sql
# /*table for the raw dataset */
# DROP TABLE IF EXISTS Turchin;
#
# CREATE TABLE Turchin (
#     Nga TEXT,
#     Polity TEXT,
#     Section TEXT,
#     Subsection TEXT,
#     Variable TEXT,
#     ValueFrom TEXT,
#     ValueTo TEXT,
#     DateFrom TEXT,
#     DateTo TEXT,
#     Ir1 TEXT,
#     Ir2 TEXT,
#     Ir3 TEXT,
#     Ir4 TEXT
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# /* table for the imputed dataset from PNAS Paper */
# DROP TABLE IF EXISTS PNAS;
#
# CREATE TABLE PNAS (
#     Nga TEXT,
#     PolID TEXT,
#     Time INT,
#     Polpop FLOAT,
#     PolTerr FLOAT,
#     CapPop FLOAT,
#     Levels FLOAT,
#     Government FLOAT,
#     Infrastr FLOAT,
#     Writing FLOAT,
#     Texts FLOAT,
#     Money FLOAT,
#     Iprep INT
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS Turchin_filtered;
# DROP TABLE IF EXISTS no_date;
#
# /* filter the table by elimininating contributors */
# CREATE TABLE Turchin_filtered AS
# SELECT Nga, Polity, Section, Subsection, Variable, ValueFrom, ValueTo, DateFrom, DateTo
# FROM Turchin
# WHERE Variable != 'RA' AND Variable != 'Editor' AND ValueFrom NOT LIKE 'unknown%' AND ValueFrom NOT LIKE 'suspected unknown%';
#
# /* filter the table by not accounting for the dates */
# CREATE TABLE no_date AS
# select Nga, Polity, Section, Subsection, Variable, ValueFrom, ValueTo
# FROM Turchin
# WHERE Variable != 'RA' AND Variable != 'Editor' AND ValueFrom NOT LIKE 'unknown%' AND ValueFrom NOT LIKE 'suspected unknown%';
# Out:
# Done.
# Done.
# 26988 rows affected.
# 26988 rows affected.
# []

# %%
# %%sql
#
# /* update the entries in the filtered Turchin dataset. */
#
# /* change the columns, subsection and variable, into lowercase to avoid human errors */
# UPDATE Turchin_filtered SET subsection = LOWER(subsection);
# UPDATE Turchin_filtered SET variable = LOWER(variable);
# UPDATE no_date SET subsection = LOWER(subsection);
# UPDATE no_date SET variable = LOWER(variable);
#
#
#
# /* filtered dataset */
# UPDATE Turchin_filtered SET ValueFrom = 1
# WHERE ValueFrom LIKE 'present%' OR ValueFrom LIKE 'inferred present%';
#
# UPDATE Turchin_filtered SET ValueFrom = 0
# WHERE ValueFrom LIKE 'absent%' OR ValueFrom LIKE 'inferred absent%';
#
# /* no date dataset */
# UPDATE no_date SET ValueFrom = 1
# WHERE ValueFrom LIKE 'present%' OR ValueFrom LIKE 'inferred present%';
#
# UPDATE no_date SET ValueFrom = 0
# WHERE ValueFrom LIKE 'absent%' OR ValueFrom LIKE 'inferred absent%';
# Out:
# 26988 rows affected.
# 26988 rows affected.
# 26988 rows affected.
# 26988 rows affected.
# 15489 rows affected.
# 7573 rows affected.
# 15489 rows affected.
# 7573 rows affected.
# []

# %%
# %%sql
#
# /* read the data from Tim on the neolithic revolution */
#
# DROP TABLE IF EXISTS Neolithic;
#
# CREATE TABLE Neolithic (
#     Site TEXT,
#     Sites TEXT,
#     Period TEXT,
#     PolJE TEXT,
#     Date_AD INT,
#     LocalNeo INT,
#     AltLocalNeo INT,
#     Gini FLOAT,
#     Lower_B FLOAT,
#     Upper_B FLOAT,
#     Basis TEXT,
#     Small_Region TEXT,
#     Intermediate_Region TEXT,
#     Big_Region TEXT,
#     World TEXT,
#     Site_Type TEXT,
#     Total_Site_Pop_HH INT,
#     Households_in_sample INT,
#     Regional_Pop_HH INT,
#     Region_size_sq_km FLOAT,
#     Region_type TEXT,
#     Data_Provider TEXT,
#     Adaptation TEXT,
#     Collective_Autocratic TEXT,
#     Chapter INT,
#     Comment TEXT
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
#
# /* filter the table Neolithic and only retain info about local origin time for neolithic as
# well as nearby origin time for neolithic */
#
# DROP TABLE IF EXISTS Neolithic_date;
#
# CREATE TABLE Neolithic_date AS
# SELECT DISTINCT small_region, intermediate_region, big_region, localneo, altlocalneo
# FROM Neolithic;
#
# SELECT *
# FROM Neolithic_date
# ORDER BY small_region
# Out:
# Done.
# 29 rows affected.
# 29 rows affected.
# [('All Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('American Bottom', 'Midwest', 'American Bottom', 800, 800),
#  ('American Bottom', 'Midwest', 'American Bottom', 700, -2250),
#  ('Anatolia', 'Near East', 'Europe & NE', -8500, -8500),
#  ('Anhui', 'Anhui', 'East Coast China', -5900, -5900),
#  ('Balikh drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Canadian Plateau/Middle Fraser Canyon', 'Other NA', 'NA foragers', 1860, 1860),
#  ('Central Mexico', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('CMV', 'SW', 'US Southwest', -500, -500),
#  ('Danube, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Egypt', 'Egypt', 'Egypt', -8000, -8000),
#  ('Gansu', 'Gansu', 'Central China', -5900, -5900),
#  ('Henan', 'Henan', 'Central China', -5900, -5900),
#  ('Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('Inner Mongolia', 'Inner Mongolia', 'Northeast China', -5700, -5700),
#  ('Inner Mongolia', 'Inner Mongolia', 'Central China', -8500, -8500),
#  ('Italy', 'Rome', 'Europe & NE', -5500, -5500),
#  ('Kalahari Desert', 'S Africa', 'Sub-Saharan Africa', 1980, 1980),
#  ('Khabur drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Lake Constance, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Maya', 'Mesoamerica', 'Mesoamerica', -1500, -1500),
#  ('Middle Euphrates', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Neckar basin, SW Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('NW Coast', 'Western NA', 'North America', 1800, 1800),
#  ('Oaxaca', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('Shandong', 'Shandong', 'East Coast China', -5900, -5900),
#  ('S Mesopotamia', 'Near East', 'Europe & NE', -6500, -6500),
#  ('Tigris, Iraq', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Wyoming', 'Other NA', 'NA foragers', 1500, 1500)]

# %%
# %%sql
#
# /* update the name of the regions to match the ones from Turchins dataset */
#
# UPDATE Neolithic_date SET small_region = 'Latium' WHERE small_region = 'Italy';
# UPDATE Neolithic_date SET small_region = 'Orkhon Valley' WHERE small_region = 'Inner Mongolia';
# UPDATE Neolithic_date SET small_region = 'Middle Yellow River Valley' WHERE small_region = 'Shandong';
#
# SELECT *
# FROM Neolithic_date
# Out:
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 29 rows affected.
# [('American Bottom', 'Midwest', 'American Bottom', 800, 800),
#  ('Central Mexico', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('Maya', 'Mesoamerica', 'Mesoamerica', -1500, -1500),
#  ('Middle Euphrates', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Wyoming', 'Other NA', 'NA foragers', 1500, 1500),
#  ('Neckar basin, SW Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Anhui', 'Anhui', 'East Coast China', -5900, -5900),
#  ('Danube, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Lake Constance, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Henan', 'Henan', 'Central China', -5900, -5900),
#  ('Balikh drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Gansu', 'Gansu', 'Central China', -5900, -5900),
#  ('Khabur drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Tigris, Iraq', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('CMV', 'SW', 'US Southwest', -500, -500),
#  ('Oaxaca', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('American Bottom', 'Midwest', 'American Bottom', 700, -2250),
#  ('S Mesopotamia', 'Near East', 'Europe & NE', -6500, -6500),
#  ('All Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('Kalahari Desert', 'S Africa', 'Sub-Saharan Africa', 1980, 1980),
#  ('Anatolia', 'Near East', 'Europe & NE', -8500, -8500),
#  ('Canadian Plateau/Middle Fraser Canyon', 'Other NA', 'NA foragers', 1860, 1860),
#  ('NW Coast', 'Western NA', 'North America', 1800, 1800),
#  ('Egypt', 'Egypt', 'Egypt', -8000, -8000),
#  ('Latium', 'Rome', 'Europe & NE', -5500, -5500),
#  ('Orkhon Valley', 'Inner Mongolia', 'Central China', -8500, -8500),
#  ('Orkhon Valley', 'Inner Mongolia', 'Northeast China', -5700, -5700),
#  ('Middle Yellow River Valley', 'Shandong', 'East Coast China', -5900, -5900)]

# %%
# %%sql
#
# /* count the number of unique subsections */
# SELECT nga, polity, count(DISTINCT subsection)
# FROM no_date
# GROUP BY nga, polity
# Out:
# 456 rows affected.
# [('Big Island Hawaii', 'Hawaii1', 6),
#  ('Big Island Hawaii', 'Hawaii2', 7),
#  ('Big Island Hawaii', 'Hawaii3', 8),
#  ('Big Island Hawaii', 'USHawai', 8),
#  ('Big Island Hawaii', 'USKameh', 8),
#  ('Cahokia', 'FrBurbL', 8),
#  ('Cahokia', 'USCahoE', 8),
#  ('Cahokia', 'USCahoL', 8),
#  ('Cahokia', 'USIllin', 7),
#  ('Cahokia', 'USMisEW', 8),
#  ('Cahokia', 'USMisME', 8),
#  ('Cahokia', 'USMisMu', 8),
#  ('Cahokia', 'USMisMW', 8),
#  ('Cahokia', 'USMisPa', 8),
#  ('Cahokia', 'USMisRo', 8),
#  ('Cahokia', 'USMisSd', 8),
#  ('Cahokia', 'USMisSL', 2),
#  ('Cahokia', 'USMisSp', 8),
#  ('Cahokia', 'USOneot', 8),
#  ('Cambodian Basin', 'KhAngkC', 8),
#  ('Cambodian Basin', 'KhAngkE', 8),
#  ('Cambodian Basin', 'KhAngkL', 8),
#  ('Cambodian Basin', 'KhCambd', 8),
#  ('Cambodian Basin', 'KhChenl', 8),
#  ('Cambodian Basin', 'KhFunaE', 8),
#  ('Cambodian Basin', 'KhFunaL', 8),
#  ('Cambodian Basin', 'ThAyuth', 8),
#  ('Cambodian Basin', 'ThRattn', 8),
#  ('Central Java', 'IdCJBun', 2),
#  ('Central Java', 'IdDemak', 4),
#  ('Central Java', 'IdKahur', 8),
#  ('Central Java', 'IdKalin', 5),
#  ('Central Java', 'IdKedir', 8),
#  ('Central Java', 'IdMajap', 8),
#  ('Central Java', 'IdMatrm', 8),
#  ('Central Java', 'IdMedng', 8),
#  ('Central Java', 'IdSingh', 8),
#  ('Chuuk Islands', 'FmTrukE', 8),
#  ('Chuuk Islands', 'FmTrukL', 8),
#  ('Cuzco', 'EsHabsb', 8),
#  ('Cuzco', 'PeCuzE1', 8),
#  ('Cuzco', 'PeCuzE2', 8),
#  ('Cuzco', 'PeCuzL1', 8),
#  ('Cuzco', 'PeCuzL2', 8),
#  ('Cuzco', 'PeCuzLF', 7),
#  ('Cuzco', 'PeInca*', 8),
#  ('Cuzco', 'Peru Cuzco chiefdom Middle Horizon (650-1000 CE)', 6),
#  ('Cuzco', 'Peru Cuzco Valley Killke (1000-1250)', 6),
#  ('Cuzco', 'Peru Cuzco Valley Killke (1250-1400)', 8),
#  ('Cuzco', 'Peru Lucre Basin (1000-1250 CE)', 5),
#  ('Cuzco', 'Peru Lucre Basin (1300-1400 CE)', 5),
#  ('Cuzco', 'PeWari*', 8),
#  ('Deccan', 'InChaBd', 8),
#  ('Deccan', 'InChaKl', 8),
#  ('Deccan', 'InDecIA', 8),
#  ('Deccan', 'InDecKg', 6),
#  ('Deccan', 'InDecNL', 7),
#  ('Deccan', 'InDelh*', 8),
#  ('Deccan', 'InHoysa', 8),
#  ('Deccan', 'InKadam', 8),
#  ('Deccan', 'InKalch', 4),
#  ('Deccan', 'InKampi', 8),
#  ('Deccan', 'InMaury', 8),
#  ('Deccan', 'InMugl*', 8),
#  ('Deccan', 'InPallE', 2),
#  ('Deccan', 'InRasht', 8),
#  ('Deccan', 'InSataL', 8),
#  ('Deccan', 'InSeuna', 5),
#  ('Deccan', 'InVakat', 8),
#  ('Deccan', 'InVijay', 8),
#  ('Finger Lakes', 'Iroquois Early Colonial', 8),
#  ('Finger Lakes', 'Pre-Colonial Finger Lakes', 8),
#  ('Finger Lakes', 'UsIroqE', 8),
#  ('Finger Lakes', 'UsIroqL', 8),
#  ('Garo Hills', 'British colonial period and early independent India', 8),
#  ('Garo Hills', 'InGaroE', 8),
#  ('Garo Hills', 'InGaroL', 8),
#  ('Garo Hills', 'Pre-colonial Garo Hills', 8),
#  ('Ghanaian Coast', 'Ashanti', 8),
#  ('Ghanaian Coast', 'GhAshnE', 7),
#  ('Ghanaian Coast', 'GhAshnL', 8),
#  ('Ghanaian Coast', 'PreAshanti', 7),
#  ('Iceland', 'IsCommw', 8),
#  ('Iceland', 'NorKing', 8),
#  ('Kachi Plain', 'AfDurrn', 8),
#  ('Kachi Plain', 'AfGhurd', 8),
#  ('Kachi Plain', 'AfGrBct', 8),
#  ('Kachi Plain', 'AfHepht', 7),
#  ('Kachi Plain', 'AfKushn', 8),
#  ('Kachi Plain', 'GrMaced', 8),
#  ('Kachi Plain', 'InDelh*', 8),
#  ('Kachi Plain', 'InMaury', 8),
#  ('Kachi Plain', 'InMugl*', 8),
#  ('Kachi Plain', 'IqAbbs1', 8),
#  ('Kachi Plain', 'IrAchae', 8),
#  ('Kachi Plain', 'IrPart1', 8),
#  ('Kachi Plain', 'IrSasn1', 8),
#  ('Kachi Plain', 'IrSasn2', 8),
#  ('Kachi Plain', 'PkAcerN', 8),
#  ('Kachi Plain', 'PkCeraN', 8),
#  ('Kachi Plain', 'PkChalc', 8),
#  ('Kachi Plain', 'PkIndGr', 8),
#  ('Kachi Plain', 'PkIndPr', 7),
#  ('Kachi Plain', 'PkPostU', 8),
#  ('Kachi Plain', 'PkPreUr', 8),
#  ('Kachi Plain', 'PkProto', 7),
#  ('Kachi Plain', 'PkSind1', 8),
#  ('Kachi Plain', 'PkSind2', 8),
#  ('Kachi Plain', 'PkUrbn1', 7),
#  ('Kachi Plain', 'PkUrbn2', 7),
#  ('Kachi Plain', 'SyCalUm', 8),
#  ('Kansai', 'JpAshik', 8),
#  ('Kansai', 'JpAsuka', 8),
#  ('Kansai', 'JpAzMom', 8),
#  ('Kansai', 'JpHeian', 8),
#  ('Kansai', 'JpJomo1', 6),
#  ('Kansai', 'JpJomo2', 7),
#  ('Kansai', 'JpJomo3', 7),
#  ('Kansai', 'JpJomo4', 7),
#  ('Kansai', 'JpJomo5', 7),
#  ('Kansai', 'JpJomo6', 7),
#  ('Kansai', 'JpKamak', 8),
#  ('Kansai', 'JpKemmu', 8),
#  ('Kansai', 'JpKofun', 8),
#  ('Kansai', 'JpNara*', 8),
#  ('Kansai', 'JpSengk', 8),
#  ('Kansai', 'JpTokgw', 8),
#  ('Kansai', 'JpYayoi', 8),
#  ('Kapuasi Basin', 'Brooke Raj and Colonial Period', 8),
#  ('Kapuasi Basin', 'IdBrokE', 8),
#  ('Kapuasi Basin', 'IdBrokL', 8),
#  ('Kapuasi Basin', 'Pre-Brooke Raj Period', 8),
#  ('Konya Plain', 'GrMaced', 8),
#  ('Konya Plain', 'IrAchae', 8),
#  ('Konya Plain', 'IrIlkhn', 7),
#  ('Konya Plain', 'IrSasn2', 8),
#  ('Konya Plain', 'IrSeleu', 8),
#  ('Konya Plain', 'IrSeljq', 8),
#  ('Konya Plain', 'ItRomLR', 8),
#  ('Konya Plain', 'ItRomPr', 8),
#  ('Konya Plain', 'MnMngKh', 8),
#  ('Konya Plain', 'TrBrzER', 6),
#  ('Konya Plain', 'TrBrzL2', 8),
#  ('Konya Plain', 'TrBrzMD', 8),
#  ('Konya Plain', 'TrByzM1', 8),
#  ('Konya Plain', 'TrByzM2', 8),
#  ('Konya Plain', 'TrByzM3', 8),
#  ('Konya Plain', 'TrCappL', 8),
#  ('Konya Plain', 'TrClcER', 8),
#  ('Konya Plain', 'TrClcLT', 8),
#  ('Konya Plain', 'TrERom*', 8),
#  ('Konya Plain', 'TrHatNK', 8),
#  ('Konya Plain', 'TrHatOK', 8),
#  ('Konya Plain', 'TrLydia', 7),
#  ('Konya Plain', 'TrLysim', 8),
#  ('Konya Plain', 'TrNeoCR', 4),
#  ('Konya Plain', 'TrNeoER', 5),
#  ('Konya Plain', 'TrNeoLT', 5),
#  ('Konya Plain', 'TrNHitt', 8),
#  ('Konya Plain', 'TrOttm1', 8),
#  ('Konya Plain', 'TrOttm2', 8),
#  ('Konya Plain', 'TrOttm3', 8),
#  ('Konya Plain', 'TrOttm4', 8),
#  ('Konya Plain', 'TrPergm', 6),
#  ('Konya Plain', 'TrPhryg', 7),
#  ('Konya Plain', 'TrPont*', 8),
#  ('Konya Plain', 'TrRomDm', 8),
#  ('Konya Plain', 'TrRum**', 8),
#  ('Konya Plain', 'TrTabal', 7),
#  ('Latium', 'ItBenLP', 6),
#  ('Latium', 'ItLatBA', 8),
#  ('Latium', 'ItLatCA', 7),
#  ('Latium', 'ItLatIA', 8),
#  ('Latium', 'ItLombr', 8),
#  ('Latium', 'ItOstrg', 8),
#  ('Latium', 'ItPapEM', 8),
#  ('Latium', 'ItPapHM', 8),
#  ('Latium', 'ItPapM1', 8),
#  ('Latium', 'ItPapM2', 8),
#  ('Latium', 'ItPapRn', 8),
#  ('Latium', 'ItRav**', 8),
#  ('Latium', 'ItRomER', 8),
#  ('Latium', 'ItRomLA', 2),
#  ('Latium', 'ItRomLR', 8),
#  ('Latium', 'ItRomMR', 8),
#  ('Latium', 'ItRomPr', 8),
#  ('Latium', 'ItRomRg', 8),
#  ('Latium', 'ItRomWe', 8),
#  ('Latium', 'ItStPet', 8),
#  ('Latium', 'TrERom*', 8),
#  ('Latium', 'TrRomDm', 8),
#  ('Lena River Valley', 'Russia Early Russian', 7),
#  ('Lena River Valley', 'Russia Pre-Russian period', 8),
#  ('Lena River Valley', 'RuYakuE', 8),
#  ('Lena River Valley', 'RuYakuL', 7),
#  ('Lena River Valley', 'RuYakut', 7),
#  ('Lowland Andes', 'Colonial Lowland Andes', 8),
#  ('Lowland Andes', 'EcJivaE', 8),
#  ('Lowland Andes', 'EcJivaL', 8),
#  ('Lowland Andes', 'Ecuadorian', 8),
#  ('Middle Yellow River Valley', 'Cn5Dyna', 6),
#  ('Middle Yellow River Valley', 'CnChuSA', 8),
#  ('Middle Yellow River Valley', 'CnChuWS', 8),
#  ('Middle Yellow River Valley', 'CnEHan*', 8),
#  ('Middle Yellow River Valley', 'CnErJin', 8),
#  ('Middle Yellow River Valley', 'CnErlig', 8),
#  ('Middle Yellow River Valley', 'CnErlit', 8),
#  ('Middle Yellow River Valley', 'CnHanWS', 7),
#  ('Middle Yellow River Valley', 'CnImQin', 8),
#  ('Middle Yellow River Valley', 'CnJinSA', 8),
#  ('Middle Yellow River Valley', 'CnLngsh', 8),
#  ('Middle Yellow River Valley', 'CnLrJin', 8),
#  ('Middle Yellow River Valley', 'CnMing*', 8),
#  ('Middle Yellow River Valley', 'CnNQi**', 6),
#  ('Middle Yellow River Valley', 'CnNSong', 8),
#  ('Middle Yellow River Valley', 'CnNWei*', 8),
#  ('Middle Yellow River Valley', 'CnNZhou', 6),
#  ('Middle Yellow River Valley', 'CnQingE', 8),
#  ('Middle Yellow River Valley', 'CnQingL', 8),
#  ('Middle Yellow River Valley', 'CnQiSA*', 8),
#  ('Middle Yellow River Valley', 'CnQiWS', 8),
#  ('Middle Yellow River Valley', 'CnShang', 8),
#  ('Middle Yellow River Valley', 'CnShu3*', 6),
#  ('Middle Yellow River Valley', 'CnSSong', 7),
#  ('Middle Yellow River Valley', 'CnSui**', 8),
#  ('Middle Yellow River Valley', 'CnTangE', 8),
#  ('Middle Yellow River Valley', 'CnTangL', 8),
#  ('Middle Yellow River Valley', 'CnWei3*', 7),
#  ('Middle Yellow River Valley', 'CnWeiWS', 8),
#  ('Middle Yellow River Valley', 'CnWHan*', 8),
#  ('Middle Yellow River Valley', 'CnWu3**', 6),
#  ('Middle Yellow River Valley', 'CnWWei*', 6),
#  ('Middle Yellow River Valley', 'CnWZhou', 8),
#  ('Middle Yellow River Valley', 'CnYngsh', 8),
#  ('Middle Yellow River Valley', 'CnYuan*', 8),
#  ('Middle Yellow River Valley', 'CnZhgSA', 7),
#  ('Middle Yellow River Valley', 'CnZhgWS', 7),
#  ('Middle Yellow River Valley', 'CnZhuSA', 7),
#  ('Middle Yellow River Valley', 'CnZhuWS', 7),
#  ('Middle Yellow River Valley', 'Eastern Jin', 6),
#  ('Middle Yellow River Valley', 'MnMngKh', 8),
#  ('Middle Yellow River Valley', 'MnMongL', 8),
#  ('Niger Inland Delta', 'MaAlmor', 8),
#  ('Niger Inland Delta', 'Mali Kingdom of Gao (1080-1236 CE)', 6),
#  ('Niger Inland Delta', 'Mali Kingdom of Gao Za Dynasty (700-1080 CE)', 6),
#  ('Niger Inland Delta', 'MaSaadi', 8),
#  ('Niger Inland Delta', 'MlAzaw1', 1),
#  ('Niger Inland Delta', 'MlAzaw2', 1),
#  ('Niger Inland Delta', 'MlAzaw3', 2),
#  ('Niger Inland Delta', 'MlBaman', 8),
#  ('Niger Inland Delta', 'MlJeJe1', 8),
#  ('Niger Inland Delta', 'MlJeJe2', 8),
#  ('Niger Inland Delta', 'MlJeJe3', 8),
#  ('Niger Inland Delta', 'MlJeJe4', 8),
#  ('Niger Inland Delta', 'MlMali*', 8),
#  ('Niger Inland Delta', 'MlMasin', 6),
#  ('Niger Inland Delta', 'MlSegou', 2),
#  ('Niger Inland Delta', 'MlSong1', 8),
#  ('Niger Inland Delta', 'MlSong2', 8),
#  ('Niger Inland Delta', 'MlSosso', 2),
#  ('Niger Inland Delta', 'MlTmbk1', 5),
#  ('Niger Inland Delta', 'MlTmbk2', 8),
#  ('Niger Inland Delta', 'MlTmbk3', 6),
#  ('Niger Inland Delta', 'MlTmbk4', 6),
#  ('Niger Inland Delta', 'MlToucl', 7),
#  ('Niger Inland Delta', 'MlTuarg', 3),
#  ('Niger Inland Delta', 'MrWagdE', 4),
#  ('Niger Inland Delta', 'MrWagdL', 8),
#  ('Niger Inland Delta', 'MrWagdM', 8),
#  ('North Colombia', 'CoNahua', 5),
#  ('North Colombia', 'CoTairo', 7),
#  ('Orkhon Valley', 'CnQingE', 8),
#  ('Orkhon Valley', 'CnQingL', 8),
#  ('Orkhon Valley', 'CnTangE', 8),
#  ('Orkhon Valley', 'CnYuan*', 8),
#  ('Orkhon Valley', 'MnETurk', 8),
#  ('Orkhon Valley', 'MnKhit1', 8),
#  ('Orkhon Valley', 'MnKhit2', 8),
#  ('Orkhon Valley', 'MnKhitn', 8),
#  ('Orkhon Valley', 'MnMngKh', 8),
#  ('Orkhon Valley', 'MnMongE', 8),
#  ('Orkhon Valley', 'MnMongL', 8),
#  ('Orkhon Valley', 'MnRourn', 8),
#  ('Orkhon Valley', 'MnShiwe', 3),
#  ('Orkhon Valley', 'MnTurk1', 8),
#  ('Orkhon Valley', 'MnTurk2', 8),
#  ('Orkhon Valley', 'MnUigur', 8),
#  ('Orkhon Valley', 'MnXianb', 8),
#  ('Orkhon Valley', 'MnXngnE', 8),
#  ('Orkhon Valley', 'MnXngnL', 8),
#  ('Orkhon Valley', 'MnXngnM', 8),
#  ('Orkhon Valley', 'MnZungh', 8),
#  ('Oro PNG', 'Oro Early Colonial', 8),
#  ('Oro PNG', 'Oro Pre-Colonial', 8),
#  ('Oro PNG', 'PgOrokE', 8),
#  ('Oro PNG', 'PgOrokL', 8),
#  ('Paris Basin', 'FrAtlBA', 8),
#  ('Paris Basin', 'FrBeakr', 8),
#  ('Paris Basin', 'FrBurbE', 8),
#  ('Paris Basin', 'FrBurbL', 8),
#  ('Paris Basin', 'FrCaptE', 8),
#  ('Paris Basin', 'FrCaptL', 8),
#  ('Paris Basin', 'FrCarlE', 8),
#  ('Paris Basin', 'FrCarlL', 8),
#  ('Paris Basin', 'FrHallA', 8),
#  ('Paris Basin', 'FrHallB', 8),
#  ('Paris Basin', 'FrHallC', 8),
#  ('Paris Basin', 'FrHallD', 8),
#  ('Paris Basin', 'FrMervE', 8),
#  ('Paris Basin', 'FrMervL', 8),
#  ('Paris Basin', 'FrMervM', 8),
#  ('Paris Basin', 'FrTeneA', 8),
#  ('Paris Basin', 'FrTeneB', 8),
#  ('Paris Basin', 'FrTeneC', 8),
#  ('Paris Basin', 'FrValoE', 8),
#  ('Paris Basin', 'FrValoL', 8),
#  ('Paris Basin', 'ItRomLA', 2),
#  ('Paris Basin', 'ItRomLR', 8),
#  ('Paris Basin', 'ItRomPr', 8),
#  ('Paris Basin', 'TrRomDm', 8),
#  ('Sogdiana', 'AfGhazn', 3),
#  ('Sogdiana', 'AfGrBct', 8),
#  ('Sogdiana', 'AfHepht', 7),
#  ('Sogdiana', 'AfKidar', 8),
#  ('Sogdiana', 'AfKushn', 8),
#  ('Sogdiana', 'AfTochr', 7),
#  ('Sogdiana', 'GrMaced', 8),
#  ('Sogdiana', 'IqAbbs1', 8),
#  ('Sogdiana', 'IrAchae', 8),
#  ('Sogdiana', 'IrIlkhn', 7),
#  ('Sogdiana', 'IrPart2', 8),
#  ('Sogdiana', 'IrSasn1', 8),
#  ('Sogdiana', 'IrSasn2', 8),
#  ('Sogdiana', 'IrSeleu', 8),
#  ('Sogdiana', 'IrSeljq', 8),
#  ('Sogdiana', 'KgKarKh', 8),
#  ('Sogdiana', 'KgWTurk', 7),
#  ('Sogdiana', 'KzAndro', 7),
#  ('Sogdiana', 'MnMngKh', 8),
#  ('Sogdiana', 'MnTurk1', 8),
#  ('Sogdiana', 'SyCalUm', 8),
#  ('Sogdiana', 'TjSaraz', 7),
#  ('Sogdiana', 'TmKhwrz', 7),
#  ('Sogdiana', 'UzChagt', 8),
#  ('Sogdiana', 'UzJanid', 8),
#  ('Sogdiana', 'UzKhw01', 6),
#  ('Sogdiana', 'UzKok01', 7),
#  ('Sogdiana', 'UzKok02', 8),
#  ('Sogdiana', 'UzSakas', 1),
#  ('Sogdiana', 'UzSamnd', 8),
#  ('Sogdiana', 'UzShayb', 4),
#  ('Sogdiana', 'UzSogdi', 8),
#  ('Sogdiana', 'UzTimur', 8),
#  ('Southern China Hills', 'CnHChin', 7),
#  ('Southern China Hills', 'CnHQngL', 8),
#  ('Southern China Hills', 'Early Chinese', 7),
#  ('Southern China Hills', 'Late Qing', 8),
#  ('Susiana', 'GrMaced', 8),
#  ('Susiana', 'IqAbbs1', 8),
#  ('Susiana', 'IqAbbs2', 8),
#  ('Susiana', 'IqAkkad', 8),
#  ('Susiana', 'IqNAssr', 8),
#  ('Susiana', 'IqUrIII', 8),
#  ('Susiana', 'IrAchae', 8),
#  ('Susiana', 'IrAkKoy', 8),
#  ('Susiana', 'IrArcha', 7),
#  ('Susiana', 'IrAwanE', 8),
#  ('Susiana', 'IrBuyid', 8),
#  ('Susiana', 'IrElmCP', 4),
#  ('Susiana', 'IrElym1', 1),
#  ('Susiana', 'IrElym2', 7),
#  ('Susiana', 'IrForma', 8),
#  ('Susiana', 'IrIlkhn', 7),
#  ('Susiana', 'IrJalay', 7),
#  ('Susiana', 'IrKhzE*', 8),
#  ('Susiana', 'IrKhzEM', 8),
#  ('Susiana', 'IrKhzL*', 8),
#  ('Susiana', 'IrKhzM*', 8),
#  ('Susiana', 'IrMedes', 6),
#  ('Susiana', 'IrMElm1', 8),
#  ('Susiana', 'IrMElm2', 8),
#  ('Susiana', 'IrMElm3', 8),
#  ('Susiana', 'IrNElm1', 5),
#  ('Susiana', 'IrNElm2', 8),
#  ('Susiana', 'IrNElm3', 5),
#  ('Susiana', 'IrPart1', 8),
#  ('Susiana', 'IrPart2', 8),
#  ('Susiana', 'IrPrCer', 8),
#  ('Susiana', 'IrSafvd', 8),
#  ('Susiana', 'IrSasn1', 8),
#  ('Susiana', 'IrSasn2', 8),
#  ('Susiana', 'IrSeleu', 8),
#  ('Susiana', 'IrSeljq', 8),
#  ('Susiana', 'IrShima', 6),
#  ('Susiana', 'IrSukkE', 8),
#  ('Susiana', 'IrSukkL', 8),
#  ('Susiana', 'IrSusa1', 8),
#  ('Susiana', 'IrSusa2', 8),
#  ('Susiana', 'IrSusa3', 8),
#  ('Susiana', 'MnMngKh', 8),
#  ('Susiana', 'SyCalUm', 8),
#  ('Susiana', 'TmKhwrz', 7),
#  ('Susiana', 'UzTimur', 8),
#  ('Upper Egypt', 'EgAyyub', 8),
#  ('Upper Egypt', 'EgBadar', 8),
#  ('Upper Egypt', 'EgDyn1*', 8),
#  ('Upper Egypt', 'EgDyn2*', 8),
#  ('Upper Egypt', 'EgHermp', 1),
#  ('Upper Egypt', 'EgIntOc', 8),
#  ('Upper Egypt', 'EgMamBh', 8),
#  ('Upper Egypt', 'EgMamBu', 8),
#  ('Upper Egypt', 'EgMamCP', 8),
#  ('Upper Egypt', 'EgMidKg', 8),
#  ('Upper Egypt', 'EgNaqa1', 8),
#  ('Upper Egypt', 'EgNaqa2', 8),
#  ('Upper Egypt', 'EgNaqa3', 8),
#  ('Upper Egypt', 'EgNKRam', 8),
#  ('Upper Egypt', 'EgNKThu', 8),
#  ('Upper Egypt', 'EgOldK1', 8),
#  ('Upper Egypt', 'EgOldK2', 8),
#  ('Upper Egypt', 'EgPtol1', 8),
#  ('Upper Egypt', 'EgPtol2', 8),
#  ('Upper Egypt', 'EgRegns', 8),
#  ('Upper Egypt', 'EgSaite', 8),
#  ('Upper Egypt', 'EgThebH', 8),
#  ('Upper Egypt', 'EgThebL', 7),
#  ('Upper Egypt', 'EgTulIk', 8),
#  ('Upper Egypt', 'GrMaced', 8),
#  ('Upper Egypt', 'IqAbbs1', 8),
#  ('Upper Egypt', 'IrAchae', 8),
#  ('Upper Egypt', 'IrSasn2', 8),
#  ('Upper Egypt', 'ItRomPr', 8),
#  ('Upper Egypt', 'SdKusht', 8),
#  ('Upper Egypt', 'SyCalUm', 8),
#  ('Upper Egypt', 'TnFatim', 8),
#  ('Upper Egypt', 'TrByzM1', 8),
#  ('Upper Egypt', 'TrERom*', 8),
#  ('Upper Egypt', 'TrOttm3', 8),
#  ('Upper Egypt', 'TrOttm4', 8),
#  ('Upper Egypt', 'TrRomDm', 8),
#  ('Valley of Oaxaca', 'MxAlb1E', 8),
#  ('Valley of Oaxaca', 'MxAlb1L', 8),
#  ('Valley of Oaxaca', 'MxAlb2*', 8),
#  ('Valley of Oaxaca', 'MxAlb3A', 8),
#  ('Valley of Oaxaca', 'MxAlb3B', 8),
#  ('Valley of Oaxaca', 'MxAlb5*', 8),
#  ('Valley of Oaxaca', 'MxAlbEP', 7),
#  ('Valley of Oaxaca', 'MxAlbLP', 8),
#  ('Valley of Oaxaca', 'MxRosar', 8),
#  ('Valley of Oaxaca', 'MxSanGu', 8),
#  ('Valley of Oaxaca', 'MxTieLa', 8),
#  ('Yemeni Coastal Plain', 'Modern Yemen', 8),
#  ('Yemeni Coastal Plain', 'Ottoman Yemen', 7),
#  ('Yemeni Coastal Plain', 'YeModrn', 8),
#  ('Yemeni Coastal Plain', 'YeOttoL', 7),
#  ('Yemeni Coastal Plain', 'YeQasmi', 7)]

# %%
# %%sql
#
# /* count the number of unique variables per subsection of polities */
# SELECT count()
# FROM no_date
# Out:
# 13 rows affected.
# [('Big Island Hawaii', 'Hawaii1', 'bureaucracy characteristics', 5),
#  ('Big Island Hawaii', 'Hawaii1', 'law', 4),
#  ('Big Island Hawaii', 'Hawaii2', 'bureaucracy characteristics', 4),
#  ('Big Island Hawaii', 'Hawaii2', 'law', 4),
#  ('Big Island Hawaii', 'Hawaii3', 'bureaucracy characteristics', 4),
#  ('Big Island Hawaii', 'Hawaii3', 'hierarchical complexity', 4),
#  ('Big Island Hawaii', 'Hawaii3', 'law', 4),
#  ('Big Island Hawaii', 'USHawai', 'bureaucracy characteristics', 2),
#  ('Big Island Hawaii', 'USHawai', 'hierarchical complexity', 1),
#  ('Big Island Hawaii', 'USHawai', 'law', 4),
#  ('Big Island Hawaii', 'USKameh', 'bureaucracy characteristics', 3),
#  ('Big Island Hawaii', 'USKameh', 'hierarchical complexity', 4),
#  ('Big Island Hawaii', 'USKameh', 'law', 4)]

# %%
# %%sql
#
# SELECT DISTINCT NGA, POLID
# FROM PNAS
# GROUP BY NGA, POLID
# Out:
# 285 rows affected.
# [('Cambodian Basin', 'KhAngkE'),
#  ('Valley of Oaxaca', 'MxSanGu'),
#  ('Middle Yellow River Valley', 'CnWeiWS'),
#  ('Latium', 'ItLatCA'),
#  ('Susiana', 'IrSukkL'),
#  ('Middle Yellow River Valley', 'CnSui**'),
#  ('Middle Yellow River Valley', 'CnLrJin'),
#  ('Kachi Plain', 'PkPreUr'),
#  ('Orkhon Valley', 'MnUigur'),
#  ('Kapuasi Basin', 'IdBrokL'),
#  ('Sogdiana', 'KgKarKh'),
#  ('Niger Inland Delta', 'MlBaman'),
#  ('Orkhon Valley', 'MnXngnL'),
#  ('Orkhon Valley', 'MnXngnE'),
#  ('Susiana', 'IrShima'),
#  ('Cahokia', 'USCahoE'),
#  ('Niger Inland Delta', 'MlSong2'),
#  ('Sogdiana', 'UzJanid'),
#  ('Susiana', 'IrForma'),
#  ('Latium', 'ItRomRg'),
#  ('Latium', 'ItRomLR'),
#  ('Kapuasi Basin', 'IdBrokE'),
#  ('Sogdiana', 'UzTimur'),
#  ('Latium', 'ItRav**'),
#  ('Deccan', 'InSataL'),
#  ('Valley of Oaxaca', 'MxAlb5*'),
#  ('Middle Yellow River Valley', 'CnShang'),
#  ('Upper Egypt', 'EgMamBu'),
#  ('Upper Egypt', 'TnFatim'),
#  ('Konya Plain', 'TrNeoLT'),
#  ('Paris Basin', 'FrHallA'),
#  ('Kachi Plain', 'InDelh*'),
#  ('Paris Basin', 'FrMervL'),
#  ('Cahokia', 'USMisMu'),
#  ('Susiana', 'IrAkKoy'),
#  ('Konya Plain', 'TrCappL'),
#  ('North Colombia', 'CoNahua'),
#  ('Valley of Oaxaca', 'MxAlb3A'),
#  ('Upper Egypt', 'EgPtol1'),
#  ('Konya Plain', 'TrNeoER'),
#  ('Big Island Hawaii', 'Hawaii2'),
#  ('Big Island Hawaii', 'Hawaii3'),
#  ('Upper Egypt', 'EgAyyub'),
#  ('Susiana', 'IrSukkE'),
#  ('Kansai', 'JpYayoi'),
#  ('Ghanaian Coast', 'GhAshnE'),
#  ('Konya Plain', 'TrHatOK'),
#  ('Middle Yellow River Valley', 'CnMing*'),
#  ('Orkhon Valley', 'MnKhit2'),
#  ('Kachi Plain', 'PkSind1'),
#  ('Cambodian Basin', 'KhChenl'),
#  ('Paris Basin', 'FrHallC'),
#  ('Susiana', 'IrSasn1'),
#  ('Cuzco', 'PeCuzLF'),
#  ('Latium', 'ItRomPr'),
#  ('Latium', 'ItPapEM'),
#  ('Susiana', 'IrKhzL*'),
#  ('Paris Basin', 'FrBurbE'),
#  ('Paris Basin', 'FrAtlBA'),
#  ('Upper Egypt', 'EgMidKg'),
#  ('Paris Basin', 'FrMervM'),
#  ('Middle Yellow River Valley', 'CnYngsh'),
#  ('Susiana', 'IrMElm1'),
#  ('Iceland', 'NorKing'),
#  ('Paris Basin', 'FrValoE'),
#  ('Deccan', 'InVijay'),
#  ('Middle Yellow River Valley', 'CnWHan*'),
#  ('Latium', 'ItLatBA'),
#  ('Southern China Hills', 'CnHQngL'),
#  ('Sogdiana', 'AfKushn'),
#  ('Valley of Oaxaca', 'MxAlb2*'),
#  ('Konya Plain', 'TrNeoCR'),
#  ('Sogdiana', 'UzSogdi'),
#  ('Paris Basin', 'FrTeneA'),
#  ('Susiana', 'IrSusa1'),
#  ('Susiana', 'IrMElm2'),
#  ('Upper Egypt', 'SdKusht'),
#  ('Upper Egypt', 'EgSaite'),
#  ('Kansai', 'JpAshik'),
#  ('Upper Egypt', 'EgThebH'),
#  ('Kansai', 'JpKofun'),
#  ('Deccan', 'InKadam'),
#  ('Susiana', 'IrArcha'),
#  ('Paris Basin', 'FrTeneC'),
#  ('Big Island Hawaii', 'USKameh'),
#  ('Konya Plain', 'TrBrzL2'),
#  ('Latium', 'ItOstrg'),
#  ('Kachi Plain', 'AfGhurd'),
#  ('Upper Egypt', 'EgNaqa2'),
#  ('Middle Yellow River Valley', 'CnTangE'),
#  ('Konya Plain', 'TrBrzMD'),
#  ('Kansai', 'JpAsuka'),
#  ('Niger Inland Delta', 'MaSaadi'),
#  ('Deccan', 'InDecIA'),
#  ('Paris Basin', 'FrValoL'),
#  ('Cambodian Basin', 'KhAngkC'),
#  ('Middle Yellow River Valley', 'CnErlit'),
#  ('Middle Yellow River Valley', 'CnJinSA'),
#  ('Susiana', 'IqAbbs2'),
#  ('Big Island Hawaii', 'Hawaii1'),
#  ('Deccan', 'InRasht'),
#  ('Kachi Plain', 'PkPostU'),
#  ('Niger Inland Delta', 'MrWagdM'),
#  ('Middle Yellow River Valley', 'CnLngsh'),
#  ('Kansai', 'JpHeian'),
#  ('Lowland Andes', 'EcJivaE'),
#  ('Konya Plain', 'TrOttm4'),
#  ('Cahokia', 'USCahoL'),
#  ('Kachi Plain', 'PkChalc'),
#  ('Deccan', 'InChaKl'),
#  ('Middle Yellow River Valley', 'CnWZhou'),
#  ('Yemeni Coastal Plain', 'YeOttoL'),
#  ('Valley of Oaxaca', 'MxAlb1E'),
#  ('Valley of Oaxaca', 'MxAlb3B'),
#  ('Upper Egypt', 'EgNKRam'),
#  ('Deccan', 'InVakat'),
#  ('Konya Plain', 'TrByzM2'),
#  ('Susiana', 'IrKhzEM'),
#  ('Latium', 'ItPapM1'),
#  ('Orkhon Valley', 'MnRourn'),
#  ('Susiana', 'IrPart1'),
#  ('Cambodian Basin', 'KhFunaE'),
#  ('Sogdiana', 'UzChagt'),
#  ('Paris Basin', 'FrCaptE'),
#  ('Susiana', 'IrSasn2'),
#  ('Middle Yellow River Valley', 'CnYuan*'),
#  ('Susiana', 'SyCalUm'),
#  ('Susiana', 'IrBuyid'),
#  ('Susiana', 'IrSafvd'),
#  ('Konya Plain', 'TrLysim'),
#  ('Valley of Oaxaca', 'MxRosar'),
#  ('Cahokia', 'USMisRo'),
#  ('Oro PNG', 'PgOrokE'),
#  ('Upper Egypt', 'EgNaqa3'),
#  ('Middle Yellow River Valley', 'CnNWei*'),
#  ('Kansai', 'JpKamak'),
#  ('Upper Egypt', 'EgRegns'),
#  ('Latium', 'ItStPet'),
#  ('Lena River Valley', 'RuYakuL'),
#  ('Paris Basin', 'FrMervE'),
#  ('Southern China Hills', 'CnHChin'),
#  ('Latium', 'ItPapRn'),
#  ('Niger Inland Delta', 'MrWagdL'),
#  ('Latium', 'ItPapM2'),
#  ('Kachi Plain', 'PkUrbn1'),
#  ('Cahokia', 'USMisPa'),
#  ('Sogdiana', 'UzKhw01'),
#  ('Cambodian Basin', 'KhAngkL'),
#  ('Deccan', 'InDecNL'),
#  ('Konya Plain', 'TrRum**'),
#  ('Valley of Oaxaca', 'MxAlb1L'),
#  ('Susiana', 'IrSusa3'),
#  ('Orkhon Valley', 'MnXngnM'),
#  ('Niger Inland Delta', 'MlJeJe3'),
#  ('Konya Plain', 'TrOttm2'),
#  ('Upper Egypt', 'EgNaqa1'),
#  ('Kachi Plain', 'PkSind2'),
#  ('Sogdiana', 'UzKok02'),
#  ('Kachi Plain', 'PkIndGr'),
#  ('Susiana', 'IrIlkhn'),
#  ('Orkhon Valley', 'MnMongL'),
#  ('Susiana', 'IrNElm3'),
#  ('Cahokia', 'USMisME'),
#  ('Konya Plain', 'TrHatNK'),
#  ('Central Java', 'IdMajap'),
#  ('Niger Inland Delta', 'MlJeJe4'),
#  ('Niger Inland Delta', 'MlJeJe2'),
#  ('Paris Basin', 'FrTeneB'),
#  ('Susiana', 'IrSusa2'),
#  ('Paris Basin', 'FrHallD'),
#  ('Orkhon Valley', 'MnMongE'),
#  ('Susiana', 'IrElym2'),
#  ('Kachi Plain', 'PkAcerN'),
#  ('Kansai', 'JpTokgw'),
#  ('Sogdiana', 'AfGrBct'),
#  ('Deccan', 'InKampi'),
#  ('Kachi Plain', 'AfDurrn'),
#  ('Orkhon Valley', 'MnETurk'),
#  ('Kachi Plain', 'PkCeraN'),
#  ('Latium', 'ItRomWe'),
#  ('Middle Yellow River Valley', 'CnNSong'),
#  ('Susiana', 'IrNElm2'),
#  ('Paris Basin', 'FrCaptL'),
#  ('Susiana', 'IqAbbs1'),
#  ('Finger Lakes', 'UsIroqL'),
#  ('Upper Egypt', 'EgIntOc'),
#  ('Cahokia', 'USMisMW'),
#  ('Yemeni Coastal Plain', 'YeQasmi'),
#  ('Cambodian Basin', 'ThRattn'),
#  ('Kansai', 'JpSengk'),
#  ('Garo Hills', 'InGaroL'),
#  ('Orkhon Valley', 'MnXianb'),
#  ('Central Java', 'IdMatrm'),
#  ('Ghanaian Coast', 'GhAshnL'),
#  ('Kachi Plain', 'InMaury'),
#  ('Deccan', 'InChaBd'),
#  ('Susiana', 'IrKhzM*'),
#  ('Susiana', 'IrKhzE*'),
#  ('Latium', 'ItRomMR'),
#  ('Valley of Oaxaca', 'MxTieLa'),
#  ('Susiana', 'IrSeljq'),
#  ('Susiana', 'IrAchae'),
#  ('Konya Plain', 'TrNHitt'),
#  ('Kansai', 'JpAzMom'),
#  ('Kachi Plain', 'InMugl*'),
#  ('Konya Plain', 'TrClcER'),
#  ('Susiana', 'IrPrCer'),
#  ('Paris Basin', 'FrBeakr'),
#  ('Kachi Plain', 'PkProto'),
#  ('Middle Yellow River Valley', 'CnQingE'),
#  ('Sogdiana', 'TjSaraz'),
#  ('Upper Egypt', 'EgMamCP'),
#  ('Lena River Valley', 'RuYakuE'),
#  ('Cambodian Basin', 'KhFunaL'),
#  ('Cuzco', 'PeCuzL2'),
#  ('Sogdiana', 'AfHepht'),
#  ('Cahokia', 'USOneot'),
#  ('Konya Plain', 'TrOttm1'),
#  ('Upper Egypt', 'EgBadar'),
#  ('Cuzco', 'PeWari*'),
#  ('Middle Yellow River Valley', 'CnQingL'),
#  ('Finger Lakes', 'UsIroqE'),
#  ('Orkhon Valley', 'MnZungh'),
#  ('Sogdiana', 'UzSamnd'),
#  ('Middle Yellow River Valley', 'CnErJin'),
#  ('Niger Inland Delta', 'MlMali*'),
#  ('Cahokia', 'USMisSp'),
#  ('Middle Yellow River Valley', 'CnEHan*'),
#  ('Sogdiana', 'UzKok01'),
#  ('Orkhon Valley', 'MnMngKh'),
#  ('Upper Egypt', 'EgOldK2'),
#  ('Lowland Andes', 'EcJivaL'),
#  ('Konya Plain', 'TrRomDm'),
#  ('Cuzco', 'PeInca*'),
#  ('Cambodian Basin', 'KhCambd'),
#  ('Konya Plain', 'TrBrzER'),
#  ('Deccan', 'InHoysa'),
#  ('Susiana', 'IrSeleu'),
#  ('Susiana', 'IqAkkad'),
#  ('Middle Yellow River Valley', 'CnErlig'),
#  ('North Colombia', 'CoTairo'),
#  ('Central Java', 'IdKedir'),
#  ('Sogdiana', 'KgWTurk'),
#  ('Upper Egypt', 'EgDyn2*'),
#  ('Garo Hills', 'InGaroE'),
#  ('Susiana', 'IrMElm3'),
#  ('Upper Egypt', 'EgDyn1*'),
#  ('Konya Plain', 'TrLydia'),
#  ('Middle Yellow River Valley', 'CnTangL'),
#  ('Cuzco', 'PeCuzE1'),
#  ('Konya Plain', 'TrTabal'),
#  ('Oro PNG', 'PgOrokL'),
#  ('Latium', 'ItPapHM'),
#  ('Central Java', 'IdMedng'),
#  ('Sogdiana', 'KzAndro'),
#  ('Susiana', 'IrNElm1'),
#  ('Sogdiana', 'AfTochr'),
#  ('Chuuk Islands', 'FmTrukL'),
#  ('Konya Plain', 'TrOttm3'),
#  ('Upper Egypt', 'EgNKThu'),
#  ('Konya Plain', 'TrPhryg'),
#  ('Paris Basin', 'FrCarlE'),
#  ('Konya Plain', 'TrByzM1'),
#  ('Upper Egypt', 'EgMamBh'),
#  ('Iceland', 'IsCommw'),
#  ('Upper Egypt', 'EgThebL'),
#  ('Konya Plain', 'TrERom*'),
#  ('Upper Egypt', 'EgOldK1'),
#  ('Cahokia', 'USMisEW'),
#  ('Niger Inland Delta', 'MlJeJe1'),
#  ('Latium', 'ItLatIA'),
#  ('Paris Basin', 'FrHallB'),
#  ('Orkhon Valley', 'MnTurk2'),
#  ('Latium', 'ItRomER'),
#  ('Susiana', 'IrAwanE'),
#  ('Cuzco', 'PeCuzL1'),
#  ('Konya Plain', 'TrClcLT'),
#  ('Upper Egypt', 'EgPtol2'),
#  ('Cuzco', 'PeCuzE2'),
#  ('Cahokia', 'USMisSd'),
#  ('Cambodian Basin', 'ThAyuth'),
#  ('Paris Basin', 'FrBurbL'),
#  ('Upper Egypt', 'EgTulIk'),
#  ('Chuuk Islands', 'FmTrukE'),
#  ('Paris Basin', 'FrCarlL')]

# %%
# %%sql
# /* create tables based on the time frame of the period. Time frame is */
# DROP IF EXISTS Stage1, Stage2, Stage3, Stage4, Stage5;
#
# SELECT count(*)
# FROM PNAS
# WHERE time < -1500;
#
#
# SELECT count(*)
# FROM PNAS
# WHERE time >= -1500 AND time < 0;
#
#
# SELECT count(*)
# FROM PNAS
# WHERE time >= 0 AND time < 1000;
#
#
# SELECT count(*)
# FROM PNAS
# WHERE time >= 1000 AND time < 1500;
#
#
# SELECT count(*)
# FROM PNAS
# WHERE time >= 1500 AND time < 2000;
#
# CREATE TABLE Stage1 AS
# SELECT *
# FROM PNAS
# WHERE TIME < -1500;
#
# CREATE TABLE Stage2 AS
# SELECT *
# FROM PNAS
# WHERE TIME >= -1500 AND TIME < 0;
#
# CREATE TABLE Stage3 AS
# SELECT *
# FROM PNAS
# WHERE time >= 0 AND time < 1000;
#
# CREATE TABLE Stage4 AS
# SELECT *
# FROM PNAS
# WHERE time >= 1000 AND time < 1500;
#
# CREATE TABLE Stage5 AS
# SELECT *
# FROM PNAS
# WHERE time >= 1500 AND time < 2000;
# Out:
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 73 rows affected.
# [(-9600, 20),
#  (-7800, 20),
#  (-7500, 20),
#  (-7200, 20),
#  (-7000, 40),
#  (-6600, 20),
#  (-6000, 40),
#  (-5700, 20),
#  (-5500, 20),
#  (-5100, 20),
#  (-5000, 60),
#  (-4700, 20),
#  (-4400, 20),
#  (-4300, 20),
#  (-4000, 20),
#  (-3900, 20),
#  (-3800, 40),
#  (-3700, 40),
#  (-3600, 60),
#  (-3500, 60),
#  (-3400, 40),
#  (-3300, 40),
#  (-3200, 80),
#  (-3100, 40),
#  (-3000, 60),
#  (-2900, 20),
#  (-2800, 20),
#  (-2700, 40),
#  (-2600, 40),
#  (-2500, 20),
#  (-2300, 20),
#  (-2200, 40),
#  (-2100, 20),
#  (-2000, 80),
#  (-1900, 40),
#  (-1800, 100),
#  (-1700, 40),
#  (-1600, 60),
#  (-1500, 60),
#  (-1400, 120),
#  (-1300, 80),
#  (-1200, 120),
#  (-1100, 80),
#  (-1000, 100),
#  (-900, 140),
#  (-800, 100),
#  (-700, 140),
#  (-600, 120),
#  (-500, 80),
#  (-400, 140),
#  (-300, 180),
#  (-200, 160),
#  (-100, 220),
#  (0, 120),
#  (100, 160),
#  (200, 120),
#  (300, 200),
#  (400, 140),
#  (500, 240),
#  (600, 240),
#  (700, 280),
#  (800, 240),
#  (900, 320),
#  (1000, 380),
#  (1100, 300),
#  (1200, 300),
#  (1300, 320),
#  (1400, 320),
#  (1500, 280),
#  (1600, 340),
#  (1700, 280),
#  (1800, 280),
#  (1900, 180)]

# %%
# %%sql
#
# /* read the data from tim */
#
# SELECT *
# FROM Neolithic_date
# Out:
# 29 rows affected.
# [('American Bottom', 'Midwest', 'American Bottom', 800, 800),
#  ('Central Mexico', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('Shandong', 'Shandong', 'East Coast China', -5900, -5900),
#  ('Maya', 'Mesoamerica', 'Mesoamerica', -1500, -1500),
#  ('Middle Euphrates', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Wyoming', 'Other NA', 'NA foragers', 1500, 1500),
#  ('Neckar basin, SW Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Anhui', 'Anhui', 'East Coast China', -5900, -5900),
#  ('Danube, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Lake Constance, Germany', 'Europe', 'Europe & NE', -5500, -5500),
#  ('Henan', 'Henan', 'Central China', -5900, -5900),
#  ('Balikh drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Gansu', 'Gansu', 'Central China', -5900, -5900),
#  ('Khabur drainage, Syria', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Tigris, Iraq', 'Near East', 'Europe & NE', -9000, -9000),
#  ('Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('CMV', 'SW', 'US Southwest', -500, -500),
#  ('Inner Mongolia', 'Inner Mongolia', 'Central China', -8500, -8500),
#  ('Oaxaca', 'Mesoamerica', 'Mesoamerica', -5000, -5000),
#  ('American Bottom', 'Midwest', 'American Bottom', 700, -2250),
#  ('Inner Mongolia', 'Inner Mongolia', 'Northeast China', -5700, -5700),
#  ('S Mesopotamia', 'Near East', 'Europe & NE', -6500, -6500),
#  ('All Hohokam', 'SW', 'US Southwest', -2000, -2000),
#  ('Italy', 'Rome', 'Europe & NE', -5500, -5500),
#  ('Kalahari Desert', 'S Africa', 'Sub-Saharan Africa', 1980, 1980),
#  ('Anatolia', 'Near East', 'Europe & NE', -8500, -8500),
#  ('Canadian Plateau/Middle Fraser Canyon', 'Other NA', 'NA foragers', 1860, 1860),
#  ('NW Coast', 'Western NA', 'North America', 1800, 1800),
#  ('Egypt', 'Egypt', 'Egypt', -8000, -8000)]

# %%
# %%sql
# DROP TABLE IF EXISTS Transition;
#
# CREATE TABLE Transition (
#     row_num INT,
#     NGA TEXT,
#     PolID TEXT,
#     Time INT,
#     Origin TEXT
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# SELECT *
# FROM Turchin tu
# INNER JOIN Transition tr ON tr.nga = tu.nga AND tr.polid = tu.polity
# WHERE variable = ANY('{Judges, Formal legal code,Practical literature,Scientific literature, Articles,
# Polity Population, Ports,
# History,
# Written records_1,
# drinking water supply systems,
# Professional Lawyers,
# Time,
# Religious literature,
# Non-phonetic writing,
# Occupational complexity,
# Drinking water supply systems,
# Irrigation systems,
# Settlement hierarchy,
# Population of the largest settlement,
# Fiction,
# Canals,
# Sacred Texts,
# Professional priesthood,
# Trading emporia,
# markets,
# food storage sites,
# Religious levels,
# Military levels,
# Phonetic alphabetic writing,
# Written records,
# Non-phonetic writing,
# Administrative levels,
# irrigation systems,
# Markets,
# Specialized government buildings,
# Professional military officers,
# Professional soldiers,
# Non-phonetic alphabetic writing,
# Script,
# Full-time bureaucrats,
# Time_1,
# Food storage sites,
# Professional lawyers,
# Population of the largest settlement_1,
# Courts}'
# ) AND tu.NGA = 'Upper Egypt' AND tr.PolID = ANY('{EgNaqa2, EgNaqa3, EgRegns, EgDyn1*}') AND variable = 'Settlement hierarchy'
# Out:
# 5 rows affected.
# [('Upper Egypt', 'EgNaqa2', 'Social Complexity variables', 'Hierarchical Complexity', 'Settlement hierarchy', '2', '3', '3550BCE', '3300BCE', 'complex', 'range', 'dates added from website', None, 780, 'Upper Egypt', 'EgNaqa2', -3400, 'Gauss1'),
#  ('Upper Egypt', 'EgNaqa3', 'Social Complexity variables', 'Hierarchical Complexity', 'Settlement hierarchy', '2', '3', '3300BCE', '3100BCE', 'complex', 'range', 'dates added from website', None, 5335, 'Upper Egypt', 'EgNaqa3', -3300, 'Gauss1'),
#  ('Upper Egypt', 'EgNaqa3', 'Social Complexity variables', 'Hierarchical Complexity', 'Settlement hierarchy', '2', '3', '3300BCE', '3100BCE', 'complex', 'range', 'dates added from website', None, 5336, 'Upper Egypt', 'EgNaqa3', -3200, 'Gauss1'),
#  ('Upper Egypt', 'EgDyn1*', 'Social Complexity variables', 'Hierarchical Complexity', 'Settlement hierarchy', '4', '5', '3100BCE', '2900BCE', 'complex', 'range', 'dates added from website', None, 5337, 'Upper Egypt', 'EgDyn1*', -3100, 'Gauss2'),
#  ('Upper Egypt', 'EgRegns', 'Social Complexity variables', 'Hierarchical Complexity', 'Settlement hierarchy', '3', None, '2150BCE', '2016BCE', 'simple', 'simple', 'dates added from website', None, 1617, 'Upper Egypt', 'EgRegns', -2100, 'Gauss1')]

# %%
# %%sql
#
# SELECT *
# FROM Turchin
# WHERE variable = 'occupational complexity'
# Out:
# 0 rows affected.
# []

# %%
EgRegns
# %%sql 

SELECT Count(nga)
From TRANSITION
ORDER BY nga
# Out:
# (psycopg2.ProgrammingError) column "transition.nga" must appear in the GROUP BY clause or be used in an aggregate function
# LINE 3: ORDER BY nga
#                  ^
#  [SQL: 'SELECT Count(nga)\nFrom TRANSITION\nORDER BY nga']
